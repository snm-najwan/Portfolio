# %%
# first import relevant packages
import pandas as pd
import numpy as np

# %%
# get the csv dataset and copy the original and peek
data = pd.read_csv("C:\\Users\\Najwan\\OneDrive\\Desktop\\Billionaires Statistics Dataset.csv")
dt = data.copy()
df = pd. DataFrame(dt)
df.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
# get the dimension of the data
df.shape
# Out:
# (2640, 35)

# %%
# get all the column headers
list(df)
# Out:
# ['rank',
#  'finalWorth',
#  'category',
#  'personName',
#  'age',
#  'country',
#  'city',
#  'source',
#  'industries',
#  'countryOfCitizenship',
#  'organization',
#  'selfMade',
#  'status',
#  'gender',
#  'birthDate',
#  'lastName',
#  'firstName',
#  'title',
#  'date',
#  'state',
#  'residenceStateRegion',
#  'birthYear',
#  'birthMonth',
#  'birthDay',
#  'cpi_country',
#  'cpi_change_country',
#  'gdp_country',
#  'gross_tertiary_education_enrollment',
#  'gross_primary_education_enrollment_country',
#  'life_expectancy_country',
#  'tax_revenue_country_country',
#  'total_tax_rate_country',
#  'population_country',
#  'latitude_country',
#  'longitude_country']

# %%
# get a little more idea about the dataset
df.describe()
# Out:
#               rank     finalWorth          age    birthYear   birthMonth  \
# count  2640.000000    2640.000000  2575.000000  2564.000000  2564.000000
# mean   1289.159091    4623.787879    65.140194  1957.183307     5.740250
# std     739.693726    9834.240939    13.258098    13.282516     3.710085
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     659.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1312.000000    2300.000000    65.000000  1957.000000     6.000000
# 75%    1905.000000    4200.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#           birthDay  cpi_country  cpi_change_country  \
# count  2564.000000  2456.000000         2456.000000
# mean     12.099844   127.755204            4.364169
# std       9.918876    26.452951            3.623763
# min       1.000000    99.550000           -1.900000
# ...

# %%
# since row count is not same for every column check for null values
for i in list(df):
    print(i, " : ", df[i].isna().sum())
# Out:
# rank  :  0
# finalWorth  :  0
# category  :  0
# personName  :  0
# age  :  65
# country  :  38
# city  :  72
# source  :  0
# industries  :  0
# countryOfCitizenship  :  0
# organization  :  2315
# selfMade  :  0
# status  :  0
# gender  :  0
# birthDate  :  76
# lastName  :  0
# firstName  :  3
# title  :  2301
# date  :  0
# state  :  1887
# residenceStateRegion  :  1893
# birthYear  :  76
# birthMonth  :  76
# birthDay  :  76
# cpi_country  :  184
# cpi_change_country  :  184
# gdp_country  :  164
# gross_tertiary_education_enrollment  :  182
# gross_primary_education_enrollment_country  :  181
# life_expectancy_country  :  182
# tax_revenue_country_country  :  183
# total_tax_rate_country  :  182
# population_country  :  164
# latitude_country  :  164
# longitude_country  :  164

# %%
# remove unwanted and columns with most null values
null_cols = ["state", "residenceStateRegion", "title", "organization", "birthYear", "birthMonth", "birthDay", "birthDate"]
df = df.drop(null_cols, axis = 1)
list(df)
# Out:
# ['rank',
#  'finalWorth',
#  'category',
#  'personName',
#  'age',
#  'country',
#  'city',
#  'source',
#  'industries',
#  'countryOfCitizenship',
#  'selfMade',
#  'status',
#  'gender',
#  'lastName',
#  'firstName',
#  'date',
#  'cpi_country',
#  'cpi_change_country',
#  'gdp_country',
#  'gross_tertiary_education_enrollment',
#  'gross_primary_education_enrollment_country',
#  'life_expectancy_country',
#  'tax_revenue_country_country',
#  'total_tax_rate_country',
#  'population_country',
#  'latitude_country',
#  'longitude_country']

# %%
# check again for null values
for i in list(df):
    print(i, " : ", df[i].isna().sum())
# Out:
# rank  :  0
# finalWorth  :  0
# category  :  0
# personName  :  0
# age  :  65
# country  :  38
# city  :  72
# source  :  0
# industries  :  0
# countryOfCitizenship  :  0
# selfMade  :  0
# status  :  0
# gender  :  0
# lastName  :  0
# firstName  :  3
# date  :  0
# cpi_country  :  184
# cpi_change_country  :  184
# gdp_country  :  164
# gross_tertiary_education_enrollment  :  182
# gross_primary_education_enrollment_country  :  181
# life_expectancy_country  :  182
# tax_revenue_country_country  :  183
# total_tax_rate_country  :  182
# population_country  :  164
# latitude_country  :  164
# longitude_country  :  164

# %%
# check how many rows are with null values
nan_rows = df.isna().any(axis=1)
k=0
for i in range(0,len(nan_rows)):
    if nan_rows[i] == True:
        k+=1
print(k)
# Out:
# 261

# %%
# so totally 261 rows with null values, remove them
cl_df = df.dropna()
cl_df.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ...  cpi_change_country           gdp_country  \
# ...

# %%
cl_df.shape
# Out:
# (2379, 27)

# %%
for i in list(df):
    print(i, " : ", df[i].dtype)
# Out:
# rank  :  int64
# finalWorth  :  int64
# category  :  object
# personName  :  object
# age  :  float64
# country  :  object
# city  :  object
# source  :  object
# industries  :  object
# countryOfCitizenship  :  object
# selfMade  :  bool
# status  :  object
# gender  :  object
# lastName  :  object
# firstName  :  object
# date  :  object
# cpi_country  :  float64
# cpi_change_country  :  float64
# gdp_country  :  object
# gross_tertiary_education_enrollment  :  float64
# gross_primary_education_enrollment_country  :  float64
# life_expectancy_country  :  float64
# tax_revenue_country_country  :  float64
# total_tax_rate_country  :  float64
# population_country  :  float64
# latitude_country  :  float64
# longitude_country  :  float64

# %%
cl_df.describe()
# Out:
#               rank     finalWorth          age  cpi_country  \
# count  2379.000000    2379.000000  2379.000000  2379.000000
# mean   1277.242119    4770.870113    65.007146   128.015511
# std     743.293794   10267.903630    13.098785    26.655791
# min       1.000000    1000.000000    18.000000    99.550000
# 25%     636.000000    1500.000000    56.000000   117.240000
# 50%    1272.000000    2400.000000    65.000000   117.240000
# 75%    1905.000000    4300.000000    74.000000   125.080000
# max    2540.000000  211000.000000   101.000000   288.570000
#
#        cpi_change_country  gross_tertiary_education_enrollment  \
# count         2379.000000                          2379.000000
# mean             4.412442                            67.395040
# std              3.503925                            21.427553
# min             -1.900000                             4.000000
# 25%              1.700000                            50.600000
# ...

# %%
# age, population cannot be float so change it into int
cl_df['age'] = cl_df['age'].astype(int)
cl_df['population_country'] = cl_df['population_country'].astype(int)

for i in list(cl_df):
    print(i, " : ", cl_df[i].dtype)
# Out:
# rank  :  int64
# finalWorth  :  int64
# category  :  object
# personName  :  object
# age  :  int32
# country  :  object
# city  :  object
# source  :  object
# industries  :  object
# countryOfCitizenship  :  object
# selfMade  :  bool
# status  :  object
# gender  :  object
# lastName  :  object
# firstName  :  object
# date  :  object
# cpi_country  :  float64
# cpi_change_country  :  float64
# gdp_country  :  object
# gross_tertiary_education_enrollment  :  float64
# gross_primary_education_enrollment_country  :  float64
# life_expectancy_country  :  float64
# tax_revenue_country_country  :  float64
# total_tax_rate_country  :  float64
# population_country  :  int32
# latitude_country  :  float64
# longitude_country  :  float64
# C:\Users\Najwan\AppData\Local\Temp\ipykernel_19364\4080642871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
cl_df.head()
# Out:
#    rank  finalWorth               category                personName  age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family   74
# 1     2      180000             Automotive                 Elon Musk   51
# 2     3      114000             Technology                Jeff Bezos   59
# 3     4      107000             Technology             Larry Ellison   78
# 4     5      106000  Finance & Investments            Warren Buffett   92
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ...  cpi_change_country           gdp_country  \
# ...

# %%
# since the ranking is wrong rerank
cl_df["rank"] = cl_df["finalWorth"].rank(ascending=False)
# cl_df["rank"].shape, cl_df["finalWorth"].shape
cl_df.head(20)
# Out:
# C:\Users\Najwan\AppData\Local\Temp\ipykernel_19364\3385431247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_df["rank"] = cl_df["finalWorth"].rank(ascending=False)
#     rank  finalWorth               category  \
# 0    1.0      211000       Fashion & Retail
# 1    2.0      180000             Automotive
# 2    3.0      114000             Technology
# 3    4.0      107000             Technology
# 4    5.0      106000  Finance & Investments
# 5    6.0      104000             Technology
# 6    7.0       94500  Media & Entertainment
# 7    8.0       93000                Telecom
# 8    9.0       83400            Diversified
# 9   10.0       80700             Technology
# 10  11.0       80500       Fashion & Retail
# ...

# %%
cl_df.describe()
# Out:
#               rank     finalWorth          age  cpi_country  \
# count  2379.000000    2379.000000  2379.000000  2379.000000
# mean   1190.000000    4770.870113    65.007146   128.015511
# std     686.605451   10267.903630    13.098785    26.655791
# min       1.000000    1000.000000    18.000000    99.550000
# 25%     600.000000    1500.000000    56.000000   117.240000
# 50%    1183.500000    2400.000000    65.000000   117.240000
# 75%    1773.000000    4300.000000    74.000000   125.080000
# max    2336.000000  211000.000000   101.000000   288.570000
#
#        cpi_change_country  gross_tertiary_education_enrollment  \
# count         2379.000000                          2379.000000
# mean             4.412442                            67.395040
# std              3.503925                            21.427553
# min             -1.900000                             4.000000
# 25%              1.700000                            50.600000
# ...

# %%
# visualize the results
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# billionairs' age with their networth
cl_df.plot(x = "age", y = "finalWorth", kind = "scatter", color = "red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xlabel = [cl_df['personName'][:10]]
xlabel
r = []
for i in xlabel:
    r.append(i)
r
# Out:
# [personName
#  Bernard Arnault & family      Bernard Arnault & family
#  Elon Musk                                    Elon Musk
#  Jeff Bezos                                  Jeff Bezos
#  Larry Ellison                            Larry Ellison
#  Warren Buffett                          Warren Buffett
#  Bill Gates                                  Bill Gates
#  Michael Bloomberg                    Michael Bloomberg
#  Carlos Slim Helu & family    Carlos Slim Helu & family
#  Mukesh Ambani                            Mukesh Ambani
#  Steve Ballmer                            Steve Ballmer
#  Name: personName, dtype: object]

# %%
cl_df.iloc[:10,:].plot(x = "personName", y = "finalWorth", kind = "bar", color = "blue",use_index = True)
# cl_df.set_index(r, inplace = True)
# plt.xlabel([cl_df['personName']], rotation = 'vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cl_df.iloc[:10,:]
# Out:
#                            rank  finalWorth               category  \
# personName
# Bernard Arnault & family    1.0      211000       Fashion & Retail
# Elon Musk                   2.0      180000             Automotive
# Jeff Bezos                  3.0      114000             Technology
# Larry Ellison               4.0      107000             Technology
# Warren Buffett              5.0      106000  Finance & Investments
# Bill Gates                  6.0      104000             Technology
# Michael Bloomberg           7.0       94500  Media & Entertainment
# Carlos Slim Helu & family   8.0       93000                Telecom
# Mukesh Ambani               9.0       83400            Diversified
# Steve Ballmer              10.0       80700             Technology
#
#                                           personName  age        country  \
# personName
# Bernard Arnault & family    Bernard Arnault & family   74         France
# ...

# %%
cl_df.iloc[:20,:].groupby(["industries"]).sum().plot.pie(y = "finalWorth", autopct = '%1.0f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.ylabel("finalWorth", rotation = 0, loc = "top")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cl_df.iloc[:20,:].groupby(["country"]).sum().plot.pie(y = "finalWorth", autopct = '%1.0f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.ylabel("finalWorth", rotation = 0, loc = "top")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cl_df.groupby(["gender"]).sum().head()
# Out:
#              rank  finalWorth     age  selfMade  cpi_country  \
# gender
# F        319512.0     1381400   17872        82     34480.94
# M       2511498.0     9968500  136780      1593    270067.96
#
#         cpi_change_country  gross_tertiary_education_enrollment  \
# gender
# F                   1188.8                              19763.4
# M                   9308.4                             140569.4
#
#         gross_primary_education_enrollment_country  life_expectancy_country  \
# gender
# F                                          28846.3                  22113.8
# M                                         215872.1                 163652.9
#
#         tax_revenue_country_country  total_tax_rate_country  \
# gender
# F                            3788.0                 12354.8
# M                           26039.3                 92200.0
#
#         population_country  latitude_country  longitude_country
# gender
# ...

# %%
cl_df.groupby(["gender"]).size().plot.bar( y = "finalWorth", use_index = True)
plt.xticks(rotation = 0)
plt.show()

# %%
cl_df[["gender","country","finalWorth"]].groupby(["country","gender"]).size().unstack().plot.bar(figsize = (12,4), stacked=True)
# Out:
# <AxesSubplot:xlabel='country'>

# %%
cl_df[["industries","gender","finalWorth"]].groupby(["industries","gender"]).size().unstack().plot.bar(stacked=True, color=['tomato','lightseagreen'])
# Out:
# <AxesSubplot:xlabel='industries'>
